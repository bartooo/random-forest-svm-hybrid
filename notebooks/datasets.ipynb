# %%
    import pandas as pd

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/ionosphere/ionosphere.data")
df
# Out:
#      1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0    1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1    1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2    1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3    1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4    1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
# ..  .. ..      ...       ...      ...      ...      ...       ...      ...
# 345  1  0  0.83508   0.08298  0.73739 -0.14706  0.84349  -0.05567  0.90441
# 346  1  0  0.95113   0.00419  0.95183 -0.02723  0.93438  -0.01920  0.94590
# 347  1  0  0.94701  -0.00034  0.93207 -0.03227  0.95177  -0.03431  0.95584
# 348  1  0  0.90608  -0.01657  0.98122 -0.01989  0.95691  -0.03646  0.85746
# 349  1  0  0.84710   0.13533  0.73638 -0.06151  0.87873   0.08260  0.88928
#
# ...

# %%
df['g'].value_counts()
# Out:
# g    224
# b    126
# Name: g, dtype: int64

# %%
df2 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00254/biodeg.csv", sep=';')
df2
# Out:
#       3.919  2.6909  0  0.1  0.2  0.3  0.4  31.4  2  0.5  ...  0.19  0.20  \
# 0     4.170  2.1144  0    0    0    0    0  30.8  1    1  ...     0     0
# 1     3.932  3.2512  0    0    0    0    0  26.7  2    4  ...     0     0
# 2     3.000  2.7098  0    0    0    0    0  20.0  0    2  ...     0     0
# 3     4.236  3.3944  0    0    0    0    0  29.4  2    4  ...     0     0
# 4     4.236  3.4286  0    0    0    0    0  28.6  2    4  ...     0     0
# ...     ...     ... ..  ...  ...  ...  ...   ... ..  ...  ...   ...   ...
# 1049  5.431  2.8955  0    0    0    2    0  32.1  4    1  ...     0     6
# 1050  5.287  3.3732  0    0    9    0    0  35.3  0    9  ...     0     3
# 1051  4.869  1.7670  0    1    9    0    5  44.4  0    4  ...     4    13
# 1052  5.158  1.6914  2    0   36    0    9  56.1  0    0  ...     1    16
# 1053  5.076  2.6588  2    0    0    0    4  54.5  0    0  ...     2     0
#
#       0.21  2.949  1.591  0.22   7.253  0.23  0.24   RB
# ...

# %%
df2['RB'].value_counts()
# Out:
# NRB    699
# RB     355
# Name: RB, dtype: int64
